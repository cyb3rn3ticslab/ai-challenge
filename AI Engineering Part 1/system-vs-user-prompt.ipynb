# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API Key is Missing")
else:
    print(OPENAI_API_KEY[:8])

client= OpenAI()
# Out:
# sk-proj-

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role":"system","content":"You are a helpful assistant"},
         {"role":"user","content":"How do I create content for my facebook post"}
        ]
)

reply = response.choices[0].message.content

display(Markdown(reply))
# Out:
# Creating content for a Facebook post involves several key steps to ensure your post is engaging, clear, and effective. Here’s a simple guide to help you create great Facebook content:
#
# 1. **Know Your Audience**
#    Understand who your followers are, what interests them, and what kind of content they engage with the most. Tailor your message to their preferences and needs.
#
# 2. **Define Your Purpose**
#    Decide what you want to achieve with your post. Are you informing, entertaining, promoting a product, or encouraging discussion?
#
# 3. **Craft a Clear and Compelling Message**
#    Write a concise and attention-grabbing headline or opening sentence. Make sure the core message is easy to understand.
#
# 4. **Use Visuals**
#    Include an eye-catching image, video, or graphic. Visual content increases engagement and makes your post more appealing.
#
# 5. **Add a Call to Action (CTA)**
#    Encourage your audience to do something, such as “Like this post,” “Share your thoughts,” “Visit our website,” or “Shop now.”
#
# 6. **Use Hashtags Wisely**
#    Hashtags can increase the reach of your post. Use relevant and trending hashtags but don’t overdo it.
#
# 7. **Keep It Conversational and Authentic**
#    Write in a friendly, natural tone. Authenticity helps build trust and connection with your audience.
#
# 8. **Edit and Proofread**
#    Check for spelling and grammar errors. A polished post reflects well on your brand.
#
# 9. **Post at the Right Time**
#    Publish your post when your audience is most active for maximum visibility.
#
# ### Example Template:
# ```
# 🌟 Exciting News! 🌟
# We’re thrilled to announce [your news]. Check out [link or details]!
# What do you think? Let us know in the comments below! 👇
# #YourBrand #ExcitingUpdates #JoinTheFun
# ```
#
# If you provide more details about the type of content or the purpose, I can help create a specific post draft for you!

# %% [markdown]
# ## Commercial use-case: IKEA Cunstomer Service Agent

# %%
question = "I bought a desk from your store last week. Can I return it?"

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role":"system", "content":"You are a customer Service Agent. You are helpful, but you strictly follow the return policy of the store. Our Return policy is: If you are not totally satisfied with your IKEA purchase you can return new and unopened products within 365 days, together with your proof of purchase, for a full refund. You may also return open products within 180 days, with your proof of purchase, for a full refund. Refunds will be made in the same form of payment originally used to make the purchase. Mattress purchases may be exchanged for another mattress one time within 90 days. Learn more here. We do not accept returns on plants, cut fabric, custom countertops and as-is products.We are unable to refund or exchange your items if your merchandise is found to be modified from its original form when purchased, dirty, stained, or damaged.  We apologize for any inconvenience."},
        {"role":"user", "content":question}
    ]
)

reply =  response.choices[0].message.content

display(Markdown(reply))
# Out:
# If your desk is in new and unopened condition, you can return it within 365 days from the date of purchase, along with your proof of purchase, for a full refund. If the desk has been opened but is still in good condition, you can return it within 180 days with your proof of purchase for a refund. Please ensure the desk is not modified, dirty, stained, or damaged, as we cannot accept returns in those conditions. Let me know if you need assistance with the return process!
